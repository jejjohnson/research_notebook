# %% [markdown]
# # MARS Satellite Constellation — Technical Characteristics
#
# The **Methane Alert and Response System (MARS)** integrates data from over 35 satellites, split into two functional categories:
#
# - **Point Source Imagers (PSI)** — high spatial resolution (20–60 m), tasked or systematic imaging, sensitivity to individual facility plumes (~100–1,000 kg/h detection floor)
# - **Area Flux Mappers (AFM)** — wide-swath column retrievals of XCH₄ (in ppb), enabling regional and national budget attribution
#
# The table below is interactive: filter by category, era, or free-text search across satellite name, instrument, and spectral method.

# %%
"""Interactive MARS satellite table — generated inline from a Python list.

Edit `SATS` to add/remove satellites; everything else is a static template.
The cell output is an HTML document rendered in a sandboxed iframe by the
mystmd frontend, so the inline <script> for filter/search runs safely.
"""
import html
import json
from IPython.display import HTML, display

SATS = [
    {"n": 1,  "name": "Landsat 4 & 5",       "era": "past",    "cat": "PSI", "spatRes": "30 m",                       "swath": "185 km",                        "specRange": "0.45–2.35 µm",            "specRes": "~100 nm (6 bands)",               "revisit": "16 days",                         "snr": "~80–100",         "inst": "TM (Thematic Mapper)",                                  "ch4": "Band 5 (1.55–1.75 µm), Band 7 (2.08–2.35 µm); indirect sensitivity only",  "cite": "landsat45", "ref_url": "https://landsat.gsfc.nasa.gov/satellites/landsat-4/"},
    {"n": 2,  "name": "Landsat 7",            "era": "past",    "cat": "PSI", "spatRes": "30 m",                       "swath": "185 km",                        "specRange": "0.45–2.35 µm",            "specRes": "~100 nm (6 VNIR/SWIR bands)",     "revisit": "16 days",                         "snr": "~100",            "inst": "ETM+",                                                  "ch4": "Band 5 (1.55–1.75 µm), Band 7 (2.09–2.35 µm)",  "cite": "landsat7", "ref_url": "https://landsat.gsfc.nasa.gov/satellites/landsat-7/"},
    {"n": 3,  "name": "Sentinel-2",           "era": "present", "cat": "PSI", "spatRes": "20 m (SWIR)",                "swath": "290 km",                        "specRange": "0.44–2.20 µm",            "specRes": "~20–90 nm (13 bands)",            "revisit": "5 days (2 sats)",                 "snr": "~100–200",        "inst": "MSI (MultiSpectral Instrument)",                        "ch4": "B11 1.61 µm, B12 2.19 µm; broadband, ~plumes >500 t/h",  "cite": "sentinel2", "ref_url": "https://sentiwiki.copernicus.eu/web/sentinel-2"},
    {"n": 4,  "name": "GHGSat",               "era": "present", "cat": "PSI", "spatRes": "~25 m",                      "swath": "12×12 km (tasked)",             "specRange": "1.63–1.67 µm",            "specRes": "~0.1 nm (Fabry-Pérot)",           "revisit": "Tasked (daily possible)",         "snr": "~300–500",        "inst": "WAF-P imaging spectrometer",                            "ch4": "1.65 µm SWIR absorption; sensitivity ~10 t/h",  "cite": "ghgsat", "ref_url": "https://www.ghgsat.com/"},
    {"n": 5,  "name": "Landsat 8 & 9",        "era": "present", "cat": "PSI", "spatRes": "30 m",                       "swath": "185 km",                        "specRange": "0.43–2.29 µm",            "specRes": "~100 nm (9 bands)",               "revisit": "16 days (8-day combined)",        "snr": "~200–300",        "inst": "OLI (Operational Land Imager)",                         "ch4": "B6 1.57–1.65 µm, B7 2.11–2.29 µm; broadband",  "cite": "landsat89", "ref_url": "https://landsat.gsfc.nasa.gov/satellites/landsat-8/"},
    {"n": 6,  "name": "Carbon Mapper",        "era": "present", "cat": "PSI", "spatRes": "~30 m",                      "swath": "~95 km",                        "specRange": "380–2,500 nm",            "specRes": "~7.5 nm (VNIR) / ~10 nm (SWIR)",  "revisit": "Daily (constellation target)",    "snr": "~400 (SWIR)",     "inst": "AVIRIS-NG heritage imaging spectrometer (Tanager-1)",   "ch4": "1.66 µm; MDL ~100–200 kg/h per point source",  "cite": "carbon_mapper", "ref_url": "https://carbonmapper.org/"},
    {"n": 7,  "name": "GaoFen-5 / GF-5B",     "era": "present", "cat": "PSI", "spatRes": "30 m",                       "swath": "60 km",                         "specRange": "400–2,500 nm",            "specRes": "~5 nm",                           "revisit": "~5 days",                         "snr": "~150",            "inst": "AHSI hyperspectral imager",                             "ch4": "1.66 µm band; point-source detection capability",  "cite": "gaofen5", "ref_url": ""},
    {"n": 8,  "name": "ZiYuan-1 (ZY-1 02D)",  "era": "present", "cat": "PSI", "spatRes": "30 m",                       "swath": "60 km",                         "specRange": "400–2,500 nm",            "specRes": "~10 nm (166 bands)",              "revisit": "~26 days",                        "snr": "~100",            "inst": "AHSI hyperspectral",                                    "ch4": "SWIR bands ~1.6–2.4 µm",  "cite": "ziyuan1", "ref_url": ""},
    {"n": 9,  "name": "EnMAP",                "era": "present", "cat": "PSI", "spatRes": "30 m",                       "swath": "30 km",                         "specRange": "420–2,450 nm",            "specRes": "~6.5 nm (228 bands)",             "revisit": "~4 days (tasked) / 27 days sys.", "snr": "~100–400",        "inst": "Pushbroom hyperspectral (VNIR + SWIR)",                 "ch4": "1.66 µm; ~100–200 kg/h detection limit",  "cite": "enmap", "ref_url": "https://www.enmap.org/"},
    {"n": 10, "name": "PRISMA",               "era": "present", "cat": "PSI", "spatRes": "30 m",                       "swath": "30 km",                         "specRange": "400–2,500 nm",            "specRes": "~10 nm (239 bands)",              "revisit": "Tasked (~29-day systematic)",     "snr": "~150–300",        "inst": "Pushbroom hyperspectral (HYC + PAN)",                   "ch4": "1.66 µm SWIR; ~200–500 kg/h detection",  "cite": "prisma", "ref_url": ""},
    {"n": 11, "name": "EMIT",                 "era": "present", "cat": "PSI", "spatRes": "60 m",                       "swath": "72 km",                         "specRange": "380–2,510 nm",            "specRes": "~7.4 nm (285 bands)",             "revisit": "~monthly (ISS orbit)",            "snr": "~300–600 (SWIR)", "inst": "Imaging spectrometer (Dyson design) on ISS",            "ch4": "1.66 µm; MDL ~100–500 kg/h; global survey",  "cite": "emit", "ref_url": "https://earth.jpl.nasa.gov/emit/"},
    {"n": 12, "name": "VIIRS",                "era": "present", "cat": "PSI", "spatRes": "375 m (I) / 750 m (M)",      "swath": "3,000 km",                      "specRange": "0.41–12.0 µm",            "specRes": "Multispectral (22 bands)",        "revisit": "~Daily (NOAA-20 + Suomi-NPP)",    "snr": "~200 (SWIR)",     "inst": "Visible Infrared Imaging Radiometer Suite",             "ch4": "M10 1.61 µm, M11 2.25 µm; super-emitter / large flares",  "cite": "viirs", "ref_url": "https://www.star.nesdis.noaa.gov/jpss/VIIRS.php"},
    {"n": 13, "name": "Sentinel-3",           "era": "present", "cat": "PSI", "spatRes": "300 m (SLSTR+OLCI)",         "swath": "1,270 km (SLSTR)",              "specRange": "0.4–12.0 µm",             "specRes": "Multispectral",                   "revisit": "~Daily (2 sats)",                 "snr": "~100",            "inst": "SLSTR + OLCI",                                          "ch4": "SWIR 1.6 µm band (F2); large plume sensitivity only",  "cite": "sentinel3", "ref_url": "https://sentiwiki.copernicus.eu/web/sentinel-3"},
    {"n": 14, "name": "GOES-16/17/18",        "era": "present", "cat": "PSI", "spatRes": "2 km (SWIR)",                "swath": "Full disk (geostationary)",     "specRange": "0.47–13.3 µm",            "specRes": "Multispectral (16 bands)",        "revisit": "5–15 min",                        "snr": "~100",            "inst": "ABI (Advanced Baseline Imager)",                        "ch4": "Band 5 1.61 µm; flare/fire monitoring; ~MW sources",  "cite": "goes_abi", "ref_url": ""},
    {"n": 15, "name": "MTG (Meteosat-I)",     "era": "future",  "cat": "PSI", "spatRes": "0.5–2 km (geostationary)",   "swath": "Full disk",                     "specRange": "0.3–13.3 µm (FCI)",       "specRes": "Multispectral + IRS sounder",     "revisit": "10 min (FCI full disk)",          "snr": "TBD",             "inst": "FCI + LI + IRS (on MTG-S)",                             "ch4": "IRS 8.0–9.6 µm thermal; area flux focus",  "cite": "mtg", "ref_url": "https://www.eumetsat.int/meteosat-third-generation"},
    {"n": 16, "name": "TANGO",                "era": "future",  "cat": "PSI", "spatRes": "~50 m (target)",             "swath": "~50 km (target)",               "specRange": "~1.60–1.70 µm",           "specRes": "~0.5 nm",                         "revisit": "Daily (4-sat constellation)",     "snr": "~300 (target)",   "inst": "Compact SWIR grating spectrometer (microsatellite)",    "ch4": "1.65 µm; point-source MDL ~100 kg/h",  "cite": "tango", "ref_url": ""},
    {"n": 17, "name": "CO2Image",             "era": "future",  "cat": "PSI", "spatRes": "~4 km",                      "swath": "~200 km",                       "specRange": "1.60–1.68 µm + 2.0 µm",   "specRes": "~0.1 nm",                         "revisit": "~Daily (planned constellation)",  "snr": "TBD",             "inst": "Compact grating spectrometer",                          "ch4": "1.65 µm; area flux and point-source blended",  "cite": "co2image", "ref_url": ""},
    {"n": 18, "name": "SBG",                  "era": "future",  "cat": "PSI", "spatRes": "~30 m",                      "swath": "~145 km",                       "specRange": "380–2,500 nm",            "specRes": "~10 nm (420+ bands)",             "revisit": "~16 days (systematic)",           "snr": "~300–500",        "inst": "Wide-swath hyperspectral (VNIR + SWIR)",                "ch4": "1.66 µm; successor to EMIT heritage",  "cite": "sbg", "ref_url": "https://sbg.jpl.nasa.gov/"},
    {"n": 19, "name": "CHIME",                "era": "future",  "cat": "PSI", "spatRes": "~20 m",                      "swath": "~45 km",                        "specRange": "400–2,500 nm",            "specRes": "~10 nm",                          "revisit": "~5 days (2 sats)",                "snr": "~300",            "inst": "Pushbroom hyperspectral (ESA Copernicus)",              "ch4": "1.66 µm SWIR band",  "cite": "chime", "ref_url": ""},
    {"n": 20, "name": "SCIAMACHY",            "era": "past",    "cat": "AFM", "spatRes": "30×60 km (nadir)",           "swath": "960 km",                        "specRange": "240–2,380 nm",            "specRes": "~0.24–1.5 nm",                    "revisit": "6 days",                          "snr": "~500–1000",       "inst": "SCIAMACHY on Envisat (2002–2012)",                      "ch4": "1.66 µm; column XCH₄; ~20 ppb precision",  "cite": "sciamachy", "ref_url": ""},
    {"n": 21, "name": "MethaneSAT",           "era": "present", "cat": "AFM", "spatRes": "~1 km",                      "swath": "~200 km",                       "specRange": "1,590–1,690 nm + O₂",     "specRes": "~0.1 nm",                         "revisit": "~Daily (key O&G basins)",         "snr": "~200–400",        "inst": "Grating spectrometer (EDF / Harvard CfA)",              "ch4": "1.65 µm; XCH₄ precision ~2 ppb; MDL ~100 kg/h area",  "cite": "methanesat", "ref_url": "https://www.methanesat.org/"},
    {"n": 22, "name": "GOSAT / IBUKI",        "era": "present", "cat": "AFM", "spatRes": "10.5 km footprint",          "swath": "Sparse (158 km spacing)",       "specRange": "0.76, 1.6, 2.0 µm + TIR", "specRes": "~0.04–0.2 nm (FTS)",              "revisit": "3 days",                          "snr": "~200–300",        "inst": "TANSO-FTS (Fourier Transform Spectrometer)",            "ch4": "1.65 µm; XCH₄ precision ~8–10 ppb; column retrieval",  "cite": "gosat", "ref_url": ""},
    {"n": 23, "name": "Sentinel-5P / TROPOMI","era": "present", "cat": "AFM", "spatRes": "5.5×3.5 km",                 "swath": "2,600 km",                      "specRange": "270–2,385 nm",            "specRes": "~0.25 nm (SWIR)",                 "revisit": "Daily global",                    "snr": "~100–1000",       "inst": "TROPOMI (TROPOspheric Monitoring Instrument)",          "ch4": "2.3 µm SWIR; XCH₄ precision ~0.6%; MDL ~1,000 kg/h",  "cite": "s5p_tropomi", "ref_url": "https://www.tropomi.eu/"},
    {"n": 24, "name": "GOSAT-GW / IBUKI-3",   "era": "future",  "cat": "AFM", "spatRes": "~3 km",                      "swath": "~50 km + wide scan",            "specRange": "0.76, 1.6, 2.0 µm + TIR", "specRes": "~0.04 nm (FTS)",                  "revisit": "~3 days",                         "snr": "~300",            "inst": "TANSO-FTS-2 + CAI-2 (launched Dec 2023)",               "ch4": "1.65 µm; improved XCH₄ precision ~5 ppb",  "cite": "gosat_gw", "ref_url": "https://www.gosat-gw.jp/en/"},
    {"n": 25, "name": "Sentinel-5 (MetOp-SG)","era": "future",  "cat": "AFM", "spatRes": "~5.5×3.5 km",                "swath": "2,600 km",                      "specRange": "270–2,385 nm",            "specRes": "~0.25 nm (SWIR)",                 "revisit": "Daily global",                    "snr": "~200",            "inst": "UVNS on MetOp-SG",                                      "ch4": "2.3 µm SWIR; successor to TROPOMI; improved radiometry",  "cite": "s5_metop_sg", "ref_url": "https://sentiwiki.copernicus.eu/web/sentinel-5"},
    {"n": 26, "name": "CO2M",                 "era": "future",  "cat": "AFM", "spatRes": "~2 km",                      "swath": "~250 km",                       "specRange": "1.61 µm + 2.0 µm + O₂",   "specRes": "~0.1 nm",                         "revisit": "~5–7 days (3 sats)",              "snr": "~300",            "inst": "Grating spectrometer (ESA Copernicus CO₂M)",            "ch4": "1.61 µm XCH₄; co-retrieved with XCO₂",  "cite": "co2m", "ref_url": ""},
    {"n": 27, "name": "MERLIN",               "era": "future",  "cat": "AFM", "spatRes": "~150 m (laser footprint)",   "swath": "N/A (lidar profiling)",         "specRange": "1,645 nm (IPDA lidar)",   "specRes": "~0.01 nm (single wavelength pair)","revisit": "~28 days (global)",              "snr": "N/A (photon counting)","inst": "IPDA lidar (French-German mission)",               "ch4": "1645 nm DIAL; column XCH₄; ~6 ppb precision target",  "cite": "merlin", "ref_url": ""},
]

CSS = """
html, body { margin: 0; padding: 0; background: transparent; }
body { padding: 0.5rem; font-family: -apple-system, BlinkMacSystemFont, "Segoe UI", sans-serif; }
#mars-sat-wrap * { box-sizing: border-box; }
#mars-sat-wrap { font-size: 13px; color: #1a1a1a; min-height: 900px; }
#mars-sat-wrap .controls { display: flex; gap: 8px; flex-wrap: wrap; padding: 0.75rem 0; align-items: center; border-bottom: 1px solid #e8e8e4; margin-bottom: 0.75rem; }
#mars-sat-wrap .btn-group { display: flex; gap: 4px; }
#mars-sat-wrap .flt { font-size: 12px; padding: 4px 10px; border-radius: 20px; border: 1px solid #ccc; background: transparent; color: #555; cursor: pointer; transition: all 0.12s; }
#mars-sat-wrap .flt.active { background: #1a1a1a; color: #fff; border-color: transparent; }
#mars-sat-wrap .search { font-size: 13px; padding: 4px 10px; border-radius: 20px; border: 1px solid #ccc; background: #fff; color: #1a1a1a; outline: none; min-width: 160px; }
#mars-sat-wrap .search::placeholder { color: #aaa; }
#mars-sat-wrap .count { font-size: 12px; color: #888; margin-left: auto; }
#mars-sat-wrap .tbl-wrap { overflow-x: auto; width: 100%; }
#mars-sat-wrap table { width: 100%; min-width: 1180px; border-collapse: collapse; font-size: 12px; }
#mars-sat-wrap th { font-size: 11px; font-weight: 600; color: #666; text-transform: uppercase; letter-spacing: 0.04em; padding: 6px 8px; border-bottom: 1.5px solid #d0d0cc; text-align: left; }
#mars-sat-wrap td { padding: 6px 8px; border-bottom: 1px solid #ebebeb; color: #1a1a1a; vertical-align: top; line-height: 1.4; }
#mars-sat-wrap tr:hover td { background: #f7f7f5; }
#mars-sat-wrap .sat-name { font-weight: 600; white-space: nowrap; }
#mars-sat-wrap .badge { display: inline-block; font-size: 10px; padding: 2px 7px; border-radius: 10px; white-space: nowrap; font-weight: 600; }
#mars-sat-wrap .b-past { background: #e8e7e0; color: #444; }
#mars-sat-wrap .b-present { background: #daeaf8; color: #1a5285; }
#mars-sat-wrap .b-future { background: #d4f0e4; color: #0e5c3a; }
#mars-sat-wrap .b-psi { background: #e8e4f8; color: #3c3489; }
#mars-sat-wrap .b-afm { background: #fef0d4; color: #7a4a06; }
#mars-sat-wrap .mono { font-family: "SFMono-Regular", Consolas, monospace; font-size: 11px; }
#mars-sat-wrap .dim { color: #bbb; font-size: 11px; }
#mars-sat-wrap .inst-cell { max-width: 180px; font-size: 11px; color: #555; }
#mars-sat-wrap .ch4-cell { max-width: 220px; font-size: 11px; }
#mars-sat-wrap .ref-cell { font-size: 11px; white-space: nowrap; }
#mars-sat-wrap .ref-cell a { color: #1a5285; text-decoration: none; border-bottom: 1px dotted #1a5285; }
#mars-sat-wrap .ref-cell a:hover { color: #0e3a6f; border-bottom-style: solid; }
"""


def _ref_link(s: dict) -> str:
    """Render the per-row reference cell. Falls back to the bare cite key
    when no URL is set, so users can still see which methane.bib entry
    backs the row."""
    cite, url = s.get("cite", ""), s.get("ref_url", "")
    if url:
        return f'<a href="{url}" target="_blank" rel="noopener" title="{cite}">link →</a>'
    if cite:
        return f'<span class="dim" title="{cite}">{cite}</span>'
    return ''


def _row(s: dict) -> str:
    cat_label = "Point source" if s["cat"] == "PSI" else "Area flux"
    cat_cls = "b-psi" if s["cat"] == "PSI" else "b-afm"
    return (
        f'<tr data-cat="{html.escape(s["cat"])}" data-era="{html.escape(s["era"])}" '
        f'data-search="{html.escape((s["name"] + " " + s["inst"] + " " + s["ch4"]).lower())}">'
        f'<td class="dim">{s["n"]}</td>'
        f'<td><span class="sat-name">{html.escape(s["name"])}</span></td>'
        f'<td><span class="badge b-{html.escape(s["era"])}">{html.escape(s["era"])}</span></td>'
        f'<td><span class="badge {cat_cls}">{cat_label}</span></td>'
        f'<td class="mono">{html.escape(s["spatRes"])}</td>'
        f'<td class="mono">{html.escape(s["swath"])}</td>'
        f'<td class="mono">{html.escape(s["specRange"])}</td>'
        f'<td class="mono">{html.escape(s["specRes"])}</td>'
        f'<td class="mono">{html.escape(s["revisit"])}</td>'
        f'<td class="mono">{html.escape(s["snr"])}</td>'
        f'<td class="inst-cell">{html.escape(s["inst"])}</td>'
        f'<td class="ch4-cell">{html.escape(s["ch4"])}</td>'
        f'<td class="ref-cell">{_ref_link(s)}</td>'
        f'</tr>'
    )


_rows_html = "\n".join(_row(s) for s in SATS)
_n = len(SATS)

# Server-side render: rows are present in the static HTML even before JS runs,
# so the table is visible without JavaScript. The <script> below only adds
# filtering/search; it doesn't generate the rows.
_doc = f"""<div id="mars-sat-wrap">
<style>{CSS}</style>
<div class="controls">
  <div class="btn-group" id="cat-grp">
    <button class="flt active" data-cat="all">All {_n}</button>
    <button class="flt" data-cat="PSI">Point source</button>
    <button class="flt" data-cat="AFM">Area flux</button>
  </div>
  <div class="btn-group" id="era-grp">
    <button class="flt active" data-era="all">All eras</button>
    <button class="flt" data-era="past">Past</button>
    <button class="flt" data-era="present">Present</button>
    <button class="flt" data-era="future">Future</button>
  </div>
  <input class="search" id="mars-search" placeholder="Search satellites…" autocomplete="off">
  <span class="count" id="mars-count">{_n} satellites</span>
</div>
<div class="tbl-wrap">
  <table id="mars-table">
    <thead><tr>
      <th>#</th><th>Satellite</th><th>Era</th><th>Type</th>
      <th>Spatial res.</th><th>Swath</th><th>Spectral range</th>
      <th>Spectral res.</th><th>Revisit</th><th>SNR (CH₄)</th>
      <th>Instrument</th><th>CH₄ band / method</th><th>Ref</th>
    </tr></thead>
    <tbody id="mars-tbody">
      {_rows_html}
    </tbody>
  </table>
</div>
<script type="application/json" id="mars-sat-data">{json.dumps(SATS, ensure_ascii=False, indent=2)}</script>
<script>
(function() {{
  var root = document.currentScript.parentNode;
  function activeFilter(grpId, attr) {{
    var el = root.querySelector('#' + grpId + ' .flt.active');
    return el ? el.dataset[attr] : 'all';
  }}
  function apply() {{
    var catF = activeFilter('cat-grp', 'cat');
    var eraF = activeFilter('era-grp', 'era');
    var q = root.querySelector('#mars-search').value.toLowerCase();
    var rows = root.querySelectorAll('#mars-tbody tr');
    var vis = 0;
    rows.forEach(function(tr) {{
      var show = (catF === 'all' || tr.dataset.cat === catF) &&
                 (eraF === 'all' || tr.dataset.era === eraF) &&
                 (q === '' || tr.dataset.search.indexOf(q) >= 0);
      tr.style.display = show ? '' : 'none';
      if (show) vis++;
    }});
    root.querySelector('#mars-count').textContent =
      vis + ' satellite' + (vis === 1 ? '' : 's');
  }}
  ['cat-grp', 'era-grp'].forEach(function(g) {{
    root.querySelectorAll('#' + g + ' .flt').forEach(function(b) {{
      b.addEventListener('click', function() {{
        root.querySelectorAll('#' + g + ' .flt')
          .forEach(function(x) {{ x.classList.remove('active'); }});
        b.classList.add('active');
        apply();
      }});
    }});
  }});
  root.querySelector('#mars-search').addEventListener('input', apply);
}})();
</script>
<!--
MARS satellite constellation — data archive
=================================================================
Self-contained, JS-enhanced table of every satellite in the MARS
(Methane Alert and Response System) tasking pool, grouped by:
  - Point Source Imagers (PSI): high-spatial-resolution instruments
    tuned to the 1.65 µm SWIR CH4 absorption window, used to localise
    individual facility emissions (~100-1000 kg/h MDL).
  - Area Flux Mappers (AFM):  wide-swath column-XCH4 retrievals, used
    for regional and national budget inversions.

Filter buttons toggle visibility client-side; the search input matches
across satellite name, instrument, and CH4 band/method. The SATS array
is mirrored above as <script type="application/json" id="mars-sat-data">
so downstream tools can ingest the data without parsing the rendered
HTML.

Data sources include published mission specifications, agency
constellation summaries (NASA, ESA, JAXA, NOAA, EDF), and operator
documentation (GHGSat, Carbon Mapper, Planet/Tanager). SNR and
detection-limit figures are approximate; revisit times for tasked
instruments depend on operator scheduling. Future-mission specs (SBG,
CHIME, CO2M, MERLIN, TANGO) are pre-launch design targets and subject
to revision. This page exists in two equivalent renderings: the
sandboxed iframe served by the mystmd build, and the inline div
embedded directly in VS Code's notebook output renderer.
-->
</div>
"""

display(HTML(_doc))
# Out:
# <div id="mars-sat-wrap">
# <style>
# html, body { margin: 0; padding: 0; background: transparent; }
# body { padding: 0.5rem; font-family: -apple-system, BlinkMacSystemFont, "Segoe UI", sans-serif; }
# #mars-sat-wrap * { box-sizing: border-box; }
# #mars-sat-wrap { font-size: 13px; color: #1a1a1a; min-height: 900px; }
# #mars-sat-wrap .controls { display: flex; gap: 8px; flex-wrap: wrap; padding: 0.75rem 0; align-items: center; border-bottom: 1px solid #e8e8e4; margin-bottom: 0.75rem; }
# #mars-sat-wrap .btn-group { display: flex; gap: 4px; }
# #mars-sat-wrap .flt { font-size: 12px; padding: 4px 10px; border-radius: 20px; border: 1px solid #ccc; background: transparent; color: #555; cursor: pointer; transition: all 0.12s; }
# #mars-sat-wrap .flt.active { background: #1a1a1a; color: #fff; border-color: transparent; }
# ...

# %% [markdown]
# ## Notes
#
# **Detection philosophy.** The two categories reflect fundamentally different retrieval strategies:
# - PSI instruments use high spatial resolution to spatially resolve individual facility plumes, with SNR and spectral resolution tuned to the 1.65 µm SWIR absorption feature.
# - AFM instruments retrieve column-averaged dry-air mole fractions (XCH₄ in ppb) across wide swaths, enabling regional budget inversion.
#
# **Spectral windows.** Nearly all instruments use either the **1.60–1.68 µm** window (lower absorption depth, cleaner for point-source retrieval) or the **2.3 µm** band (deeper absorption, preferred for regional XCH₄ columns, used by TROPOMI/Sentinel-5). MERLIN is unique in using an IPDA lidar with matched on/off wavelengths at 1645 nm rather than passive solar backscatter.
#
# **Caveats.**
# - SNR figures are scene- and band-dependent; many instruments publish full spectrally-resolved SNR curves.
# - Revisit times for tasked instruments (GHGSat, PRISMA, Carbon Mapper) depend entirely on operator scheduling.
# - Future mission specs (SBG, CHIME, CO2M, MERLIN, TANGO) are from pre-launch design documents and subject to revision.
# - GOSAT-GW launched December 2023 but was still in commissioning as of early 2024; some specs are pre-launch.
# - EMIT revisit is irregular due to ISS precession drift — coverage varies from 1–4 passes/month depending on latitude.
